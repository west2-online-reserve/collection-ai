# %% [markdown]
#  所有库

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import expit 
import datetime

r_f=pd.read_csv(r"C:\Users\宋志坤\Desktop\新建文件夹\学习\新建文件夹\qwq.csv")

# %% [markdown]
#  通知人比例

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import expit  # 计算Logistic函数
import datetime

r_f=pd.read_csv(r"C:\Users\宋志坤\Desktop\新建文件夹\学习\新建文件夹\qwq.csv")

holder_num=r_f['Holder'].value_counts(normalize=True)*100
print("通知人比例：")
print(holder_num)
# Out:
# 通知人比例：
# Holder
# 教学运行    32.0
# 实践科     25.8
# 计划科     12.0
# 质量办     10.0
# 教研教改     8.6
# 综合科      7.4
# 教材中心     4.0
# 教学通知     0.2
# Name: proportion, dtype: float64

# %% [markdown]
#  下载次数和发表人关系

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import expit  # 计算Logistic函数
import datetime
plt.rcParams['font.sans-serif'] = ['SimHei']

r_f=pd.read_csv(r"C:\Users\宋志坤\Desktop\新建文件夹\学习\新建文件夹\qwq.csv")

holder_loadnum=r_f.groupby("Holder")["下载次数"].sum()
print(holder_loadnum)
sns.boxplot(x='Holder', y='下载次数', data=r_f)
plt.xticks(rotation=45)
plt.title('附件下载次数与通知人关系')
plt.show()
# Out:
# Holder
# 实践科     64138
# 教学运行    78650
# 教学通知      357
# 教材中心     9883
# 教研教改    19659
# 综合科     13054
# 计划科     34433
# 质量办     11776
# Name: 下载次数, dtype: int64

# %% [markdown]
#  不同日期通知密集程度

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import expit  # 计算Logistic函数
import datetime
plt.rcParams['font.sans-serif'] = ['SimHei']
r_f=pd.read_csv(r"C:\Users\宋志坤\Desktop\新建文件夹\学习\新建文件夹\qwq.csv")
r_f['Date']=pd.to_datetime(r_f['Date'])
r_f["Date"]=r_f["Date"].dt.date
time_series=r_f.groupby("Date").size()
plt.figure(figsize=(12, 6))
time_series.plot(kind='line', color='b')
plt.title('每日通知数')
plt.xlabel('日期')
plt.ylabel('通知数')
plt.grid(True)
plt.show()

# %% [markdown]
#  不同年份通知密集程度（自己提出感兴趣的问题）

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import expit  # 计算Logistic函数
import datetime

r_f=pd.read_csv(r"C:\Users\宋志坤\Desktop\新建文件夹\学习\新建文件夹\qwq.csv")
r_f['Date']=pd.to_datetime(r_f['Date'])
r_f["Date"]=r_f["Date"].dt.year
year_series=r_f.groupby("Date").size()
print(year_series)
# Out:
# Date
# 2022.0     94
# 2023.0    204
# 2024.0    202
# dtype: int64

# %% [markdown]
#  logistic函数

# %%
x=np.linspace(-10,10,400)
y=1/(1+expit(-1*x))
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
#  不同曲线

# %%
x=np.linspace(-10,10,400)
y=2/(1+expit(-2*x))
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
#——--------------------------------------------
x=np.linspace(-10,10,400)
y=0.5/(1+expit(-2*x))
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
#--------------------------------------------------
x=np.linspace(-10,10,400)
y=2/(1+expit(-0.5*x))
plt.figure(figsize=(8,6))
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
