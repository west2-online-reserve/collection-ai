# %% [markdown]
# # jupyter使用基础
# ## 单元格基础
# ### cell 单元格模式切换
# 按ESC进入命令模式
# 按Enter进入编辑模式
# 也可以用鼠标点击 点左边变成选择 点单元格内变成编辑模式
# ### cell 单元格的类型
# 有code类型和markdown类型
# 在选中状态按m进入markdown类型
# 按y进入code类型
# ### 单元格操作
# * A键：在当前单元格上方插入一个单元格。
# * B 键：在当前单元格下方插入一个单元格。（用任何方式新插入的单元格，均默认
# 为Code类型。）
# * Shift+↑键或Shift+↓键：向上或向下连续选择多个单元格。
# * D, D键：即在命令模式下连按两次D键，删除选中的单元格。
# * Z键：恢复删除的单元格。
# * X键：剪切选中的单元格。
# * C键：复制选中的单元格。
# * V键：将剪切或复制的单元格粘贴到当前单元格下方。
# 如下几个快捷键，用于运行代码。这几个快捷键在命令模式或编辑模式下都可以直接
# 使用。
# * Ctrl+Enter 键：运行选中的单元格中的代码。
# * Shift+Enter 键：运行选中的单元格中的代码，然后选中下一个单元格。
# * Alt+Enter 键：运行选中的单元格中的代码，然后在其下方插入一个新的单元格。

# %% [markdown]
# # markdown学习
#
# ## 二级标题
#
# ### 三级标题
#
# #### 四级标题
#
# ##### 五级标题
#
# ###### 六级标题
#
# #号加空格  多少#就是几级标题
#
# 最多六级
#
# ## 字体
#
# *hello world！*
#
# **hello world**
#
# ***hello world！***
#
# ~~hello world！~~
#
#  两边**粗体
#
# 两边*斜体
#
# 两边***又粗又斜
#
# 两边~~划掉
#
# ## 引用
#
# 大于符号
#
# > 就像这样分割线
#
# ## 分割线
#
# 三个减号或者三个星号
#
# ---
#
# ***
#
#
#
# ## 图片
#
# ！[图片名字]()
#
# ## 超链接
#
# [标题](地址)
#
# ## 列表
#
# 1. 数字加句号加空格
# 2. 一个回车下一个
# 3. 两个回车取消掉
#
# 就像这样
#
# - 减号加空格变成点
# - 两下回车也可以不点
#
# 也像这样
#
# ## 表格
#
# | 名字 | 性别 | 生日 |
# | ---- | ---- | ---- |
# | 张三 | 男   | 1997 |
#
# 一般用右键
#
# | 名字 | 性别 | 生日 |
#
# | ---- | ---- | ---- |
#
# | 张三 | 男   | 1997 |
#
# ## 代码
#
# 三个tab上方的点加语言
#
# ```c
# #include <stdio.h>
# int main()
# {
# return 0；
# }
# ```
